# %%
import pandas as pd
data_frame = pd.read_csv("olympicMedals.csv")
data_frame.shape
# Out:
# (1807, 9)

# %%
pd.read_csv("olympicMedals.csv")
# Out:
#                    edition  edition_id  year        country country_noc  gold  \
# 0     1896 Summer Olympics           1  1896  United States         USA    11
# 1     1896 Summer Olympics           1  1896         Greece         GRE    10
# 2     1896 Summer Olympics           1  1896        Germany         GER     6
# 3     1896 Summer Olympics           1  1896         France         FRA     5
# 4     1896 Summer Olympics           1  1896  Great Britain         GBR     2
# ...                    ...         ...   ...            ...         ...   ...
# 1802     1906 Intercalated           4  1906         Canada         CAN     1
# 1803     1906 Intercalated           4  1906         Norway         NOR     1
# 1804     1906 Intercalated           4  1906    Netherlands         NED     0
# 1805     1906 Intercalated           4  1906      Australia         AUS     0
# 1806     1906 Intercalated           4  1906        Bohemia         BOH     0
#
#       silver  bronze  total
# ...

# %%
data_frame.describe()
# Out:
#         edition_id         year         gold       silver       bronze  \
# count  1807.000000  1807.000000  1807.000000  1807.000000  1807.000000
# mean     31.635307  1979.744328     3.737133     3.721638     3.971223
# std      18.472012    32.726372     7.554092     6.411636     6.169554
# min       1.000000  1896.000000     0.000000     0.000000     0.000000
# 25%      17.000000  1960.000000     0.000000     1.000000     1.000000
# 50%      25.000000  1988.000000     1.000000     2.000000     2.000000
# 75%      53.000000  2008.000000     4.000000     4.000000     5.000000
# max      62.000000  2022.000000    83.000000    85.000000    83.000000
#
#              total
# count  1807.000000
# mean     11.429994
# std      19.423201
# min       1.000000
# 25%       2.000000
# 50%       5.000000
# 75%      13.000000
# max     248.000000

# %%
data_frame.values
# Out:
# array([['1896 Summer Olympics', 1, 1896, ..., 7, 2, 20],
#        ['1896 Summer Olympics', 1, 1896, ..., 18, 19, 47],
#        ['1896 Summer Olympics', 1, 1896, ..., 5, 2, 13],
#        ...,
#        ['1906 Intercalated', 4, 1906, ..., 1, 2, 3],
#        ['1906 Intercalated', 4, 1906, ..., 0, 3, 3],
#        ['1906 Intercalated', 4, 1906, ..., 0, 2, 2]], dtype=object)

# %%
data_frame[data_frame["year"]>1900].head()
# Out:
#                  edition  edition_id  year        country country_noc  gold  \
# 30  1904 Summer Olympics           3  1904  United States         USA    80
# 31  1904 Summer Olympics           3  1904        Germany         GER     5
# 32  1904 Summer Olympics           3  1904         Canada         CAN     4
# 33  1904 Summer Olympics           3  1904           Cuba         CUB     3
# 34  1904 Summer Olympics           3  1904        Hungary         HUN     2
#
#     silver  bronze  total
# 30      85      83    248
# 31       4       5     14
# 32       1       1      6
# 33       0       0      3
# 34       1       1      4

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x=data_frame["year"], y=data_frame["total"])
graph
# Out:
# <Axes: xlabel='year', ylabel='total'>

# %%
graph = sns.scatterplot(x=data_frame["gold"], y=data_frame["total"])
graph
# Out:
# <Axes: xlabel='gold', ylabel='total'>

# %%
graph = sns.scatterplot(x=data_frame["year"], y=data_frame["gold"])
graph
# Out:
# <Axes: xlabel='year', ylabel='gold'>

# %%
graph = sns.scatterplot(x=data_frame["gold"], y=data_frame["total"])
graph
# Out:
# <Axes: xlabel='gold', ylabel='total'>

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Year, Gold)", "(@year, @gold)"),
])
p = figure(title="Olympic Medal Data", x_axis_label="Year", y_axis_label="Gold", width=1000, height=700, tools=[hover])
p.circle("year", "gold", size=10, source=data_frame)
show(p)

# %%
from sklearn.datasets import load_iris
iris = load_iris()

x = iris.data
y = iris.target

feature_names = iris.feature_names
target_names = iris.target_names
feature_names
target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')
